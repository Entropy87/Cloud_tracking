# %%
# This is loading the trained model and running some picture and video inforamtion

from ultralytics import YOLO
import cv2

#model = YOLO("yolov9c.pt")  
#model = YOLO("yolov9c-seg.pt")
model = YOLO("Cloudv9.pt")

# %%
video_path = "cyclone.mp4"
cap = cv2.VideoCapture(video_path)

# %%
import cv2

video_path = "cyclone.mp4"
cap = cv2.VideoCapture(video_path)

frame_skip = 2  # Number of frames to skip, set to 1 to process every frame
frame_count = 0

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Skip frames
        frame_count += 1
        if frame_count % frame_skip != 0:
            continue

        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 14 Clouds, 616.5ms
# Speed: 10.9ms preprocess, 616.5ms inference, 53.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 Clouds, 437.9ms
# Speed: 3.0ms preprocess, 437.9ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 Clouds, 454.1ms
# Speed: 2.0ms preprocess, 454.1ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 Clouds, 476.1ms
# Speed: 2.0ms preprocess, 476.1ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 463.7ms
# Speed: 2.0ms preprocess, 463.7ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 485.6ms
# Speed: 2.0ms preprocess, 485.6ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 Clouds, 521.2ms
# Speed: 2.0ms preprocess, 521.2ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 494.9ms
# ...
