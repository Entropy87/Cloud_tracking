# %%
# This is loading the trained model and running some picture and video inforamtion

from ultralytics import YOLO
import cv2

model = YOLO("yolov9c.pt")  
model = YOLO("yolov9c-seg.pt")
model = YOLO("Cloudv9.pt")

# %%
video_path = "cyclone.mp4"
cap = cv2.VideoCapture(video_path)

# %%
import cv2

video_path = "cyclone.mp4"
cap = cv2.VideoCapture(video_path)

frame_skip = 2  # Number of frames to skip, set to 1 to process every frame
frame_count = 0

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Skip frames
        frame_count += 1
        if frame_count % frame_skip != 0:
            continue

        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 320x640 14 Clouds, 1718.1ms
# Speed: 11.2ms preprocess, 1718.1ms inference, 52.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 Clouds, 1536.5ms
# Speed: 4.0ms preprocess, 1536.5ms inference, 28.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 16 Clouds, 1616.7ms
# Speed: 3.8ms preprocess, 1616.7ms inference, 30.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 Clouds, 1538.8ms
# Speed: 3.0ms preprocess, 1538.8ms inference, 29.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1470.6ms
# Speed: 2.1ms preprocess, 1470.6ms inference, 23.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1477.2ms
# Speed: 2.0ms preprocess, 1477.2ms inference, 23.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 Clouds, 1517.3ms
# Speed: 3.2ms preprocess, 1517.3ms inference, 28.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1504.1ms
# Speed: 3.0ms preprocess, 1504.1ms inference, 23.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1504.2ms
# Speed: 1.5ms preprocess, 1504.2ms inference, 22.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 Clouds, 1472.5ms
# Speed: 2.0ms preprocess, 1472.5ms inference, 24.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 14 Clouds, 1527.7ms
# Speed: 3.2ms preprocess, 1527.7ms inference, 25.4ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1494.7ms
# Speed: 2.0ms preprocess, 1494.7ms inference, 25.5ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1489.1ms
# Speed: 2.4ms preprocess, 1489.1ms inference, 23.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1479.0ms
# Speed: 3.4ms preprocess, 1479.0ms inference, 22.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1545.3ms
# Speed: 3.2ms preprocess, 1545.3ms inference, 26.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 Clouds, 1475.8ms
# Speed: 2.0ms preprocess, 1475.8ms inference, 23.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1483.0ms
# Speed: 3.3ms preprocess, 1483.0ms inference, 23.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 Clouds, 1526.9ms
# Speed: 3.1ms preprocess, 1526.9ms inference, 25.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 13 Clouds, 1497.6ms
# Speed: 2.4ms preprocess, 1497.6ms inference, 23.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 12 Clouds, 1492.0ms
# Speed: 2.5ms preprocess, 1492.0ms inference, 22.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 Clouds, 1488.1ms
# Speed: 3.0ms preprocess, 1488.1ms inference, 29.1ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 17 Clouds, 1483.1ms
# Speed: 2.4ms preprocess, 1483.1ms inference, 32.3ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 15 Clouds, 1471.7ms
# Speed: 2.5ms preprocess, 1471.7ms inference, 29.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 22 Clouds, 1497.3ms
# Speed: 3.0ms preprocess, 1497.3ms inference, 39.9ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 19 Clouds, 1509.6ms
# Speed: 2.5ms preprocess, 1509.6ms inference, 36.6ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 18 Clouds, 1485.5ms
# Speed: 3.0ms preprocess, 1485.5ms inference, 35.7ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 19 Clouds, 1512.1ms
# Speed: 2.7ms preprocess, 1512.1ms inference, 39.2ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 21 Clouds, 1579.7ms
# Speed: 2.3ms preprocess, 1579.7ms inference, 46.6ms postprocess per image at shape (1, 3, 320, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 24
#      21 results = model(frame)
#      23 # Visualize the results on the frame
# ---> 24 annotated_frame = results[0].plot()
#      26 # Display the annotated frame
#      27 cv2.imshow("YOLOv8 Inference", annotated_frame)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\engine\results.py:274, in Results.plot(self, conf, line_width, font_size, font, pil, img, im_gpu, kpt_radius, kpt_line, labels, boxes, masks, probs, show, save, filename)
#     266         im_gpu = (
#     267             torch.as_tensor(img, dtype=torch.float16, device=pred_masks.data.device)
#     268             .permute(2, 0, 1)
#    (...)
#     271             / 255
#     272         )
#     273     idx = pred_boxes.cls if pred_boxes else range(len(pred_masks))
# --> 274     annotator.masks(pred_masks.data, colors=[colors(x, True) for x in idx], im_gpu=im_gpu)
#     276 # Plot Detect results
#     277 if pred_boxes is not None and show_boxes:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\ultralytics\utils\plotting.py:230, in Annotator.masks(self, masks, colors, im_gpu, alpha, retina_masks)
#     227 masks = masks.unsqueeze(3)  # shape(n,h,w,1)
#     228 masks_color = masks * (colors * alpha)  # shape(n,h,w,3)
# --> 230 inv_alpha_masks = (1 - masks * alpha).cumprod(0)  # shape(n,h,w,1)
#     231 mcs = masks_color.max(dim=0).values  # shape(n,h,w,3)
#     233 im_gpu = im_gpu.flip(dims=[0])  # flip channel
#
# KeyboardInterrupt:
